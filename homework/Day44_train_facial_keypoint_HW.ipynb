# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0060 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00207, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00207 to 0.00194, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00194 to 0.00186, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00186 to 0.00184, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00184 to 0.00181, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5862e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00181 to 0.00170, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.1713e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00170 to 0.00158, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 7.2717e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00158 to 0.00144, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 6.3156e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00144 to 0.00130, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.6981e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00130 to 0.00121, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.2104e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00121 to 0.00118, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.8446e-04 - val_loss: 0.0010
#
# Epoch 00012: val_loss improved from 0.00118 to 0.00105, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.4632e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00105 to 0.00103, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.1823e-04 - val_loss: 9.7174e-04
#
# Epoch 00014: val_loss improved from 0.00103 to 0.00097, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.1416e-04 - val_loss: 9.4279e-04
#
# Epoch 00015: val_loss improved from 0.00097 to 0.00094, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.7495e-04 - val_loss: 9.2320e-04
#
# Epoch 00016: val_loss improved from 0.00094 to 0.00092, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.5612e-04 - val_loss: 8.7819e-04
#
# Epoch 00017: val_loss improved from 0.00092 to 0.00088, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.5532e-04 - val_loss: 8.5479e-04
#
# Epoch 00018: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.3520e-04 - val_loss: 8.4805e-04
#
# Epoch 00019: val_loss improved from 0.00085 to 0.00085, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.1919e-04 - val_loss: 8.6123e-04
#
# Epoch 00020: val_loss did not improve from 0.00085
# Epoch 21/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.0636e-04 - val_loss: 8.2601e-04
#
# Epoch 00021: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8935e-04 - val_loss: 8.3452e-04
#
# Epoch 00022: val_loss did not improve from 0.00083
# Epoch 23/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.0927e-04 - val_loss: 8.3693e-04
#
# Epoch 00023: val_loss did not improve from 0.00083
# Epoch 24/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8559e-04 - val_loss: 8.5654e-04
#
# Epoch 00024: val_loss did not improve from 0.00083
# Epoch 25/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8014e-04 - val_loss: 7.6584e-04
#
# Epoch 00025: val_loss improved from 0.00083 to 0.00077, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.6571e-04 - val_loss: 8.4389e-04
#
# Epoch 00026: val_loss did not improve from 0.00077
# Epoch 27/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.6258e-04 - val_loss: 7.8641e-04
#
# Epoch 00027: val_loss did not improve from 0.00077
# Epoch 28/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.6291e-04 - val_loss: 8.0844e-04
#
# Epoch 00028: val_loss did not improve from 0.00077
# Epoch 29/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.5529e-04 - val_loss: 8.1760e-04
#
# Epoch 00029: val_loss did not improve from 0.00077
# Epoch 30/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.4432e-04 - val_loss: 7.9971e-04
#
# Epoch 00030: val_loss did not improve from 0.00077
# Epoch 31/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.4339e-04 - val_loss: 7.5304e-04
#
# Epoch 00031: val_loss improved from 0.00077 to 0.00075, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3999e-04 - val_loss: 7.8055e-04
#
# Epoch 00032: val_loss did not improve from 0.00075
# Epoch 33/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2814e-04 - val_loss: 7.7098e-04
#
# Epoch 00033: val_loss did not improve from 0.00075
# Epoch 34/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2471e-04 - val_loss: 8.0373e-04
#
# Epoch 00034: val_loss did not improve from 0.00075
# Epoch 35/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2556e-04 - val_loss: 7.8865e-04
#
# Epoch 00035: val_loss did not improve from 0.00075
# Epoch 36/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1733e-04 - val_loss: 7.5103e-04
#
# Epoch 00036: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1640e-04 - val_loss: 7.5387e-04
#
# Epoch 00037: val_loss did not improve from 0.00075
# Epoch 38/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2187e-04 - val_loss: 7.9640e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1800e-04 - val_loss: 7.7962e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0709e-04 - val_loss: 8.0860e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
# Epoch 41/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0537e-04 - val_loss: 7.6886e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9663e-04 - val_loss: 7.3939e-04
#
# Epoch 00042: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9377e-04 - val_loss: 7.3578e-04
#
# Epoch 00043: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9434e-04 - val_loss: 7.7393e-04
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9513e-04 - val_loss: 7.1750e-04
# Epoch 00045: val_loss improved from 0.00074 to 0.00072, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9603e-04 - val_loss: 7.6532e-04
#
# Epoch 00046: val_loss did not improve from 0.00072
# Epoch 47/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9507e-04 - val_loss: 7.1707e-04
#
# Epoch 00047: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9091e-04 - val_loss: 7.5532e-04
#
# Epoch 00048: val_loss did not improve from 0.00072
# Epoch 49/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8725e-04 - val_loss: 7.0941e-04
#
# Epoch 00049: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8094e-04 - val_loss: 7.5133e-04
#
# Epoch 00050: val_loss did not improve from 0.00071
# Epoch 51/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7897e-04 - val_loss: 7.3226e-04
#
# Epoch 00051: val_loss did not improve from 0.00071
# Epoch 52/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7892e-04 - val_loss: 7.1618e-04
#
# Epoch 00052: val_loss did not improve from 0.00071
# Epoch 53/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7918e-04 - val_loss: 7.3336e-04
#
# Epoch 00053: val_loss did not improve from 0.00071
# Epoch 54/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7340e-04 - val_loss: 7.4421e-04
#
# Epoch 00054: val_loss did not improve from 0.00071
# Epoch 55/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7599e-04 - val_loss: 6.9591e-04
#
# Epoch 00055: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6841e-04 - val_loss: 7.2966e-04
#
# Epoch 00056: val_loss did not improve from 0.00070
# Epoch 57/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6844e-04 - val_loss: 7.2179e-04
#
# Epoch 00057: val_loss did not improve from 0.00070
# Epoch 58/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6894e-04 - val_loss: 7.2174e-04
#
# Epoch 00058: val_loss did not improve from 0.00070
# Epoch 59/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6586e-04 - val_loss: 7.2380e-04
#
# Epoch 00059: val_loss did not improve from 0.00070
# Epoch 60/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6282e-04 - val_loss: 7.3619e-04
#
# Epoch 00060: val_loss did not improve from 0.00070
# Epoch 61/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6225e-04 - val_loss: 7.5951e-04
#
# Epoch 00061: val_loss did not improve from 0.00070
# Epoch 62/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6024e-04 - val_loss: 7.6036e-04
#
# Epoch 00062: val_loss did not improve from 0.00070
# Epoch 63/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5685e-04 - val_loss: 7.3103e-04
#
# Epoch 00063: val_loss did not improve from 0.00070
# Epoch 64/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5826e-04 - val_loss: 7.4929e-04
#
# Epoch 00064: val_loss did not improve from 0.00070
# Epoch 65/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5093e-04 - val_loss: 7.0772e-04
#
# Epoch 00065: val_loss did not improve from 0.00070
# Epoch 66/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5063e-04 - val_loss: 7.0587e-04
#
# Epoch 00066: val_loss did not improve from 0.00070
# Epoch 67/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4827e-04 - val_loss: 7.1208e-04
#
# Epoch 00067: val_loss did not improve from 0.00070
# Epoch 68/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4709e-04 - val_loss: 7.2076e-04
#
# Epoch 00068: val_loss did not improve from 0.00070
# Epoch 69/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4455e-04 - val_loss: 7.3010e-04
#
# Epoch 00069: val_loss did not improve from 0.00070
# Epoch 70/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4437e-04 - val_loss: 7.1766e-04
#
# Epoch 00070: val_loss did not improve from 0.00070
# Epoch 71/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4270e-04 - val_loss: 7.6057e-04
#
# Epoch 00071: val_loss did not improve from 0.00070
# Epoch 72/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3954e-04 - val_loss: 7.3543e-04
#
# Epoch 00072: val_loss did not improve from 0.00070
# Epoch 73/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4273e-04 - val_loss: 7.2243e-04
#
# Epoch 00073: val_loss did not improve from 0.00070
# Epoch 74/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4061e-04 - val_loss: 7.8572e-04
#
# Epoch 00074: val_loss did not improve from 0.00070
# Epoch 75/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4023e-04 - val_loss: 7.1521e-04
#
# Epoch 00075: val_loss did not improve from 0.00070
# Epoch 76/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3692e-04 - val_loss: 7.2873e-04
#
# Epoch 00076: val_loss did not improve from 0.00070
# Epoch 77/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3813e-04 - val_loss: 7.8963e-04
#
# Epoch 00077: val_loss did not improve from 0.00070
# Epoch 78/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3584e-04 - val_loss: 7.2699e-04
#
# Epoch 00078: val_loss did not improve from 0.00070
# Epoch 79/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3553e-04 - val_loss: 6.9320e-04
#
# Epoch 00079: val_loss improved from 0.00070 to 0.00069, saving model to best_weights.h5
# Epoch 80/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3482e-04 - val_loss: 6.9808e-04
#
# Epoch 00080: val_loss did not improve from 0.00069
# Epoch 81/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3145e-04 - val_loss: 6.9996e-04
#
# Epoch 00081: val_loss did not improve from 0.00069
# Epoch 82/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3087e-04 - val_loss: 7.4590e-04
#
# Epoch 00082: val_loss did not improve from 0.00069
# Epoch 83/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3351e-04 - val_loss: 7.1529e-04
#
# Epoch 00083: val_loss did not improve from 0.00069
# Epoch 84/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3167e-04 - val_loss: 6.9294e-04
#
# Epoch 00084: val_loss improved from 0.00069 to 0.00069, saving model to best_weights.h5
# Epoch 85/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2847e-04 - val_loss: 7.3398e-04
#
# Epoch 00085: val_loss did not improve from 0.00069
# Epoch 86/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2823e-04 - val_loss: 7.0153e-04
#
# Epoch 00086: val_loss did not improve from 0.00069
# Epoch 87/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3029e-04 - val_loss: 7.2577e-04
#
# Epoch 00087: val_loss did not improve from 0.00069
# Epoch 88/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2527e-04 - val_loss: 7.1093e-04
#
# Epoch 00088: val_loss did not improve from 0.00069
# Epoch 89/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2712e-04 - val_loss: 6.9440e-04
#
# Epoch 00089: val_loss did not improve from 0.00069
# Epoch 90/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2690e-04 - val_loss: 7.0951e-04
#
# Epoch 00090: val_loss did not improve from 0.00069
# Epoch 91/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2664e-04 - val_loss: 7.1444e-04
#
# Epoch 00091: val_loss did not improve from 0.00069
# Epoch 92/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2344e-04 - val_loss: 7.0446e-04
#
# Epoch 00092: val_loss did not improve from 0.00069
# Epoch 93/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2562e-04 - val_loss: 7.4151e-04
#
# Epoch 00093: val_loss did not improve from 0.00069
# Epoch 94/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2384e-04 - val_loss: 7.5990e-04
#
# Epoch 00094: val_loss did not improve from 0.00069
# Epoch 95/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1864e-04 - val_loss: 7.2381e-04
#
# Epoch 00095: val_loss did not improve from 0.00069
# Epoch 96/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1656e-04 - val_loss: 6.9988e-04
#
# Epoch 00096: val_loss did not improve from 0.00069
# Epoch 97/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1535e-04 - val_loss: 7.1896e-04
#
# Epoch 00097: val_loss did not improve from 0.00069
# Epoch 98/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1661e-04 - val_loss: 7.3533e-04
#
# Epoch 00098: val_loss did not improve from 0.00069
# Epoch 99/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1625e-04 - val_loss: 7.0153e-04
#
# Epoch 00099: val_loss did not improve from 0.00069
# Epoch 100/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1643e-04 - val_loss: 7.2394e-04
#
# Epoch 00100: val_loss did not improve from 0.00069
# Epoch 101/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1451e-04 - val_loss: 7.1220e-04
#
# Epoch 00101: val_loss did not improve from 0.00069
# Epoch 102/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1146e-04 - val_loss: 7.3899e-04
#
# Epoch 00102: val_loss did not improve from 0.00069
# Epoch 103/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0992e-04 - val_loss: 7.1154e-04
#
# Epoch 00103: val_loss did not improve from 0.00069
# Epoch 104/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0712e-04 - val_loss: 7.3452e-04
#
# Epoch 00104: val_loss did not improve from 0.00069
# Epoch 105/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0764e-04 - val_loss: 6.9984e-04
#
# Epoch 00105: val_loss did not improve from 0.00069
# Epoch 106/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0870e-04 - val_loss: 7.1176e-04
#
# Epoch 00106: val_loss did not improve from 0.00069
# Epoch 107/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0858e-04 - val_loss: 7.2191e-04
#
# Epoch 00107: val_loss did not improve from 0.00069
# Epoch 108/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1064e-04 - val_loss: 7.0231e-04
#
# Epoch 00108: val_loss did not improve from 0.00069
# Epoch 109/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0768e-04 - val_loss: 7.3095e-04
#
# Epoch 00109: val_loss did not improve from 0.00069
# Epoch 110/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0673e-04 - val_loss: 7.5860e-04
#
# Epoch 00110: val_loss did not improve from 0.00069
# Epoch 111/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0734e-04 - val_loss: 7.1279e-04
#
# Epoch 00111: val_loss did not improve from 0.00069
# Epoch 112/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0426e-04 - val_loss: 7.4264e-04
#
# Epoch 00112: val_loss did not improve from 0.00069
# Epoch 113/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0385e-04 - val_loss: 7.2686e-04
#
# Epoch 00113: val_loss did not improve from 0.00069
# Epoch 114/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0465e-04 - val_loss: 7.5598e-04
#
# Epoch 00114: val_loss did not improve from 0.00069
# Epoch 115/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0306e-04 - val_loss: 7.6214e-04
#
# Epoch 00115: val_loss did not improve from 0.00069
# Epoch 116/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0331e-04 - val_loss: 7.3963e-04
#
# Epoch 00116: val_loss did not improve from 0.00069
# Epoch 117/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0105e-04 - val_loss: 7.1456e-04
#
# Epoch 00117: val_loss did not improve from 0.00069
# Epoch 118/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0342e-04 - val_loss: 7.2415e-04
#
# Epoch 00118: val_loss did not improve from 0.00069
# Epoch 119/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7700e-05 - val_loss: 7.4100e-04
#
# Epoch 00119: val_loss did not improve from 0.00069
# Epoch 120/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.8198e-05 - val_loss: 7.2277e-04
#
# Epoch 00120: val_loss did not improve from 0.00069
# Epoch 121/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0408e-04 - val_loss: 7.2887e-04
#
# Epoch 00121: val_loss did not improve from 0.00069
# Epoch 122/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0166e-04 - val_loss: 7.6829e-04
#
# Epoch 00122: val_loss did not improve from 0.00069
# Epoch 123/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9694e-05 - val_loss: 7.4543e-04
#
# Epoch 00123: val_loss did not improve from 0.00069
# Epoch 124/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0029e-04 - val_loss: 7.3871e-04
#
# Epoch 00124: val_loss did not improve from 0.00069
# Epoch 125/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6151e-05 - val_loss: 7.2483e-04
#
# Epoch 00125: val_loss did not improve from 0.00069
# Epoch 126/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4627e-05 - val_loss: 7.3199e-04
#
# Epoch 00126: val_loss did not improve from 0.00069
# Epoch 127/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6788e-05 - val_loss: 7.4373e-04
#
# Epoch 00127: val_loss did not improve from 0.00069
# Epoch 128/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7093e-05 - val_loss: 7.0529e-04
#
# Epoch 00128: val_loss did not improve from 0.00069
# Epoch 129/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.8656e-05 - val_loss: 7.2041e-04
#
# Epoch 00129: val_loss did not improve from 0.00069
# Epoch 130/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4999e-05 - val_loss: 7.4129e-04
#
# Epoch 00130: val_loss did not improve from 0.00069
# Epoch 131/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2194e-05 - val_loss: 7.2834e-04
#
# Epoch 00131: val_loss did not improve from 0.00069
# Epoch 132/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4446e-05 - val_loss: 7.1000e-04
#
# Epoch 00132: val_loss did not improve from 0.00069
# Epoch 133/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2077e-05 - val_loss: 7.2944e-04
#
# Epoch 00133: val_loss did not improve from 0.00069
# Epoch 134/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8748e-05 - val_loss: 7.1345e-04
#
# Epoch 00134: val_loss did not improve from 0.00069
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3682e-05 - val_loss: 7.1818e-04
#
# Epoch 00135: val_loss did not improve from 0.00069
# Epoch 136/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1118e-05 - val_loss: 7.0595e-04
#
# Epoch 00136: val_loss did not improve from 0.00069
# Epoch 137/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2753e-05 - val_loss: 7.5241e-04
#
# Epoch 00137: val_loss did not improve from 0.00069
# Epoch 138/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0162e-05 - val_loss: 7.4136e-04
#
# Epoch 00138: val_loss did not improve from 0.00069
# Epoch 139/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0683e-05 - val_loss: 7.4167e-04
#
# Epoch 00139: val_loss did not improve from 0.00069
# Epoch 140/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8826e-05 - val_loss: 7.3607e-04
#
# Epoch 00140: val_loss did not improve from 0.00069
# Epoch 141/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0863e-05 - val_loss: 7.4941e-04
#
# Epoch 00141: val_loss did not improve from 0.00069
# Epoch 142/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8593e-05 - val_loss: 7.1750e-04
#
# Epoch 00142: val_loss did not improve from 0.00069
# Epoch 143/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.5079e-05 - val_loss: 7.7641e-04
#
# Epoch 00143: val_loss did not improve from 0.00069
# Epoch 144/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7805e-05 - val_loss: 7.2271e-04
#
# Epoch 00144: val_loss did not improve from 0.00069
# Epoch 145/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7421e-05 - val_loss: 7.2421e-04
#
# Epoch 00145: val_loss did not improve from 0.00069
# Epoch 146/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9179e-05 - val_loss: 7.3407e-04
#
# Epoch 00146: val_loss did not improve from 0.00069
# Epoch 147/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.3403e-05 - val_loss: 7.4686e-04
#
# Epoch 00147: val_loss did not improve from 0.00069
# Epoch 148/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6159e-05 - val_loss: 7.4967e-04
#
# Epoch 00148: val_loss did not improve from 0.00069
# Epoch 149/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6428e-05 - val_loss: 7.5318e-04
#
# Epoch 00149: val_loss did not improve from 0.00069
# Epoch 150/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7689e-05 - val_loss: 7.5432e-04
#
# Epoch 00150: val_loss did not improve from 0.00069

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
# 讀取資料
imgs_train2, points_train2 = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
def hflip(image,points):
    image=image[: , : , ::-1]
    for i in range(points.shape[0]):
        for j in range(0,points.shape[1],2):
            points[i][j]=-points[i][j]
    return image,points

# %%
plot_keypoints(imgs_train[0],points_train[0])

# %%
new_imgs,new_points=hflip(imgs_train2,points_train2)
plot_keypoints(new_imgs[0],new_points[0])

# %%
imgs_train_f = np.vstack([imgs_train, new_imgs])
points_train_f = np.vstack([points_train, new_points])

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# training the model
hist_model = model_with_augment.fit(imgs_train_f.reshape(-1, 96, 96, 1), 
                       points_train_f, 
                       validation_split=0.1, batch_size=64,
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('new_weights.h5')
# save the model
model.save('new_model.h5')
# Out:
# Train on 3852 samples, validate on 428 samples
# Epoch 1/150
# 3852/3852 [==============================] - 15s 4ms/step - loss: 0.0199 - val_loss: 0.0247
# Epoch 2/150
# 3852/3852 [==============================] - 15s 4ms/step - loss: 0.0150 - val_loss: 0.0346
# Epoch 3/150
# 3852/3852 [==============================] - 15s 4ms/step - loss: 0.0082 - val_loss: 0.0388
# Epoch 4/150
# 3264/3852 [========================>.....] - ETA: 2s - loss: 0.0057

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
